# %% [markdown]
# ## Deep Learning Fundamentals Assignment 2

# %% [markdown]
# Training a Classifier
# =====================
#
# We will be defining neural networks, computing loss and updating the weights of the network.
#
# ----------------
# Specifically for vision, PyTorch includes a package called
# ``torchvision``, that has data loaders for common datasets such as
# Imagenet, CIFAR10, MNIST, etc. and data transformers for images, viz.,
# ``torchvision.datasets`` and ``torch.utils.data.DataLoader``.
#
# You can also implement your own dataloader based on ``torch.utils.data.DataLoader``.
#
# This provides a huge convenience and avoids writing boilerplate code.
#
# We will use the CINIC-10 dataset.
# It has the classes: ‘airplane’, ‘automobile’, ‘bird’, ‘cat’, ‘deer’,
# ‘dog’, ‘frog’, ‘horse’, ‘ship’, ‘truck’. The images in CINIC-10 are of
# size 3x32x32, i.e. 3-channel color images of 32x32 pixels in size.
#
#
#
# Training an image classifier
# ----------------------------
#
# We will do the following steps in order:
#
# 1. Load and normalizing the CIFAR10 training and test datasets using
#    ``torchvision``
# 2. Define a Convolutional Neural Network
# 3. Define a loss function
# 4. Train the network on the training data
# 5. Test the network on the test data
#
# 1. Loading and normalizing CIFAR10
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# Using ``torchvision``, it’s extremely easy to load CINIC-10.

# %% [markdown]
# ### Importing Libraries

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms, datasets

# %% [markdown]
# ### Loading and Preparing Dataset

# %%
import torchvision
import torchvision.transforms as transforms

cinic_dir = 'D:/MDS/2023/4th Tri-3/DLF/Ass2/DS_10283_3192'
traindir = cinic_dir + '/train'
validatedir = cinic_dir + '/valid'
testdir = cinic_dir + '/test'

cinic_mean = [0.47889522, 0.47227842, 0.43047404]
cinic_std = [0.24205776, 0.23828046, 0.25874835]
normalize = transforms.Normalize(mean=cinic_mean, std=cinic_std)

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=cinic_mean, std=cinic_std)
])

train_transform = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean=cinic_mean, std=cinic_std)
])

trainset = datasets.ImageFolder(root=traindir, transform=train_transform)
trainloader = torch.utils.data.DataLoader(trainset,
                                          batch_size=64,
                                          shuffle=True,
                                          num_workers=2)

validateset = datasets.ImageFolder(root=validatedir, transform=transform)
validateloader = torch.utils.data.DataLoader(validateset,
                                             batch_size=64,
                                             shuffle=True,
                                             num_workers=2)

testset = datasets.ImageFolder(root=testdir, transform=transform)
testloader = torch.utils.data.DataLoader(testset,
                                         batch_size=64,
                                         shuffle=True,
                                         num_workers=2)

classes = ('airplane', 'automobile', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# %% [markdown]
# ### Ensuring GPU is being used to train

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %% [markdown]
# ### Printing some training images

# %%
import matplotlib.pyplot as plt
import numpy as np

# functions to show an image
def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# get some random training images
dataiter = iter(trainloader)
images, labels = next(dataiter)

# select the first 4 images
images = images[:4]
labels = labels[:4]

# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   dog   cat airplane  frog

# %% [markdown]
# ### Defining the Convolutional Neural Network

# %%
import torch.nn.functional as F


class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, 3)
        self.conv2 = nn.Conv2d(32, 32, 3)
        self.pool = nn.MaxPool2d(2, 2)
        self.dropout1 = nn.Dropout2d(0.2)
        self.conv3 = nn.Conv2d(32, 64, 3)
        self.pool2 = nn.MaxPool2d(2, 2)
        self.conv4 = nn.Conv2d(64, 128, 3)
        self.conv5 = nn.Conv2d(128, 128, 3)
        self.pool3 = nn.MaxPool2d(2, 2)
        self.dropout2 = nn.Dropout2d(0.2)
        self.adaptive_pool = nn.AdaptiveAvgPool2d((4, 4))
        self.fc1 = nn.Linear(128 * 4 * 4, 128)
        self.fc2 = nn.Linear(128, 64)
        self.fc3 = nn.Linear(64, 16)
        self.dropout3 = nn.Dropout(0.2)
        self.fc4 = nn.Linear(16, 10)

    def forward(self, x):
        x = x.to(self.conv1.weight.device)  # add this line
        x = F.relu(self.conv1(x))
        # print(x.shape)
        x = F.relu(self.conv2(x))
        # print(x.shape)
        x = self.pool(x)
        x = self.dropout1(x)
        x = F.relu(self.conv3(x))
        # print(x.shape)
        x = self.pool2(x)
        x = F.relu(self.conv4(x))
        # print(x.shape)
        x = F.relu(self.conv5(x))
        # print(x.shape)
        x = self.pool3(x)
        x = self.dropout2(x)
        x = self.adaptive_pool(x)
        x = x.view(-1, 128 * 4 * 4)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = self.dropout3(x)
        x = self.fc4(x)
        return x

net = Net()
print(net)
# Out:
# Net(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout1): Dropout2d(p=0.2, inplace=False)
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv4): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1))
#   (conv5): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#   (pool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout2): Dropout2d(p=0.2, inplace=False)
#   (adaptive_pool): AdaptiveAvgPool2d(output_size=(4, 4))
#   (fc1): Linear(in_features=2048, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=16, bias=True)
#   (dropout3): Dropout(p=0.2, inplace=False)
#   (fc4): Linear(in_features=16, out_features=10, bias=True)
# )

# %%
# import torch.nn.functional as F


# class Net(nn.Module):
#     def __init__(self):
#         super(Net, self).__init__()
#         self.conv1 = nn.Conv2d(3, 6, 5)
#         self.pool = nn.MaxPool2d(2, 2)
#         self.conv2 = nn.Conv2d(6, 16, 5)
#         self.fc1 = nn.Linear(16 * 5 * 5, 120)
#         self.fc2 = nn.Linear(120, 84)
#         self.fc3 = nn.Linear(84, 10)

#     def forward(self, x):
#         x = self.pool(F.relu(self.conv1(x)))
#         x = self.pool(F.relu(self.conv2(x)))
#         x = x.view(-1, 16 * 5 * 5)
#         x = F.relu(self.fc1(x))
#         x = F.relu(self.fc2(x))
#         x = self.fc3(x)
#         return x


# net = Net()
# print(net)

# %%
#TODO CHECK THE ERROR OM TORCHVIEW

# %% [markdown]
# ### Visualizing the model

# %%
# #https://torchview.dev/
# #https://github.com/mert-kurttutan/torchview
from torchview import draw_graph
model_graph = draw_graph(net, input_size=(3,32,32), expand_nested=True)
model_graph.visual_graph
# Out:
# c:\PythonEnvironments\TorchEnv\lib\site-packages\torch\nn\functional.py:1352: UserWarning: dropout2d: Received a 3D input to dropout2d and assuming that channel-wise 1D dropout behavior is desired - input is interpreted as shape (N, C, L), where C is the channel dim. This behavior will change in a future release to interpret the input as one without a batch dimension, i.e. shape (C, H, W). To maintain the 1D channel-wise dropout behavior, please switch to using dropout1d instead.
#   warnings.warn("dropout2d: Received a 3D input to dropout2d and assuming that channel-wise "
#
# (dot.exe:16256): Pango-WARNING **: couldn't load font "Linux libertine Not-Rotated 10", falling back to "Sans Not-Rotated 10", expect ugly output.

# %%
from torchsummary import summary

net = Net()
summary(net, input_size=(3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 30, 30]             896
#             Conv2d-2           [-1, 32, 28, 28]           9,248
#          MaxPool2d-3           [-1, 32, 14, 14]               0
#          Dropout2d-4           [-1, 32, 14, 14]               0
#             Conv2d-5           [-1, 64, 12, 12]          18,496
#          MaxPool2d-6             [-1, 64, 6, 6]               0
#             Conv2d-7            [-1, 128, 4, 4]          73,856
#             Conv2d-8            [-1, 128, 2, 2]         147,584
#          MaxPool2d-9            [-1, 128, 1, 1]               0
#         Dropout2d-10            [-1, 128, 1, 1]               0
# AdaptiveAvgPool2d-11            [-1, 128, 4, 4]               0
#            Linear-12                  [-1, 128]         262,272
#            Linear-13                   [-1, 64]           8,256
#            Linear-14                   [-1, 16]           1,040
#           Dropout-15                   [-1, 16]               0
#            Linear-16                   [-1, 10]             170
# ================================================================
# Total params: 521,818
# Trainable params: 521,818
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.63
# Params size (MB): 1.99
# Estimated Total Size (MB): 2.64
# ----------------------------------------------------------------

# %%
#https://appsilon.com/visualize-pytorch-neural-networks/
#TODO Visulaize
# from torchviz import make_dot

# model = Net()
# y = model(X)

# %%
# from torchviz import make_dot
# #https://stackoverflow.com/questions/52468956/how-do-i-visualize-a-net-in-pytorch

# #Backward pass apparently,
# # TODO check on this later
# batch = next(iter(dataloader_train))
# yhat = model(batch.text) # Give dummy batch to forward().

# make_dot(yhat, params=dict(list(model.named_parameters()))).render("cnn_torchviz", format="png")

# %%
# import hiddenlayer as hl
# #https://stackoverflow.com/questions/52468956/how-do-i-visualize-a-net-in-pytorch

# #Forward pass apparently,
# # TODO check on this later
# transforms = [ hl.transforms.Prune('Constant') ] # Removes Constant nodes from graph.

# graph = hl.build_graph(model, batch.text, transforms=transforms)
# graph.theme = hl.graph.THEMES['blue'].copy()
# graph.save('rnn_hiddenlayer', format='png')

# %% [markdown]
# ### Defining a Loss function and optimizer

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.01, momentum=0.9, weight_decay=0.001)
# torch.cuda.empty_cache()
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
net.to(device)
# inputs = inputs.to(device)
# outputs = net(inputs)
print(device)
# Out:
# cuda:0

# %% [markdown]
# ### Training the model

# %%
epoch_num = 200

def accuracy(outputs, labels):
    _, predicted = torch.max(outputs, 1)
    correct = (predicted == labels).sum().item()
    total = labels.size(0)
    return correct / total
             
def recall(outputs, labels):
    _, predicted = torch.max(outputs, 1)
    true_positives = ((predicted == labels) & (labels == 1)).sum().item()
    false_negatives = ((predicted != labels) & (labels == 1)).sum().item()
    denominator = true_positives + false_negatives
    if denominator == 0:
        return 0
    else:
        return true_positives / denominator

def precision(outputs, labels):
    _, predicted = torch.max(outputs, 1)
    true_positives = ((predicted == labels) & (labels == 1)).sum().item()
    false_positives = ((predicted != labels) & (labels == 0)).sum().item()
    denominator = true_positives + false_positives
    if denominator == 0:
        return 0
    else:
        return true_positives / denominator
        
def train_model_one_epoch(model, trainloader, optimizer, criterion, device):
    model.train()
    
    result = {'loss': 0,
             'accuracy': 0,
             'recall': 0,
             'precision': 0}
    for i, data in enumerate(trainloader):
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = model(inputs)
        
        loss = criterion(outputs, labels)
        result['loss'] += loss.item()
        result['accuracy'] += accuracy(outputs, labels)
        result['recall'] += recall(outputs, labels)
        result['precision'] += precision(outputs, labels)

        loss.backward()
        optimizer.step()
        
    result = {k: v / len(trainloader) for k, v in result.items()}
    return result 

def valid_model(model, validloader, criterion, device):
    result = {'loss': 0,
             'accuracy': 0,
             'recall': 0,
             'precision': 0}
    model.eval()
    with torch.no_grad():
        for i, data in enumerate(validloader):
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)

            loss = criterion(outputs, labels)
            result['loss'] += loss.item()
            result['accuracy'] += accuracy(outputs, labels)
            result['recall'] += recall(outputs, labels)
            result['precision'] += precision(outputs, labels)

    result = {k: v / len(validloader) for k, v in result.items()}
    return result

def train_model(model, trainloader, validloader, optimizer, criterion, num_epochs, device):
    best_valid_perform = None
    train_losses = []
    valid_losses = []
    for epoch in range(num_epochs):
        train_perform = train_model_one_epoch(model, trainloader, optimizer, criterion, device)
        valid_perform = valid_model(model, validloader, criterion, device)
        if best_valid_perform is None or valid_perform['accuracy'] > best_valid_perform['accuracy']:
            best_valid_perform = valid_perform
            torch.save(model.state_dict(), 'best_valid.pt')
        print(f'Epoch {epoch+1}: Train Loss={train_perform["loss"]:.4f}, Train Acc={train_perform["accuracy"]:.4f}, Valid Loss={valid_perform["loss"]:.4f}, Valid Acc={valid_perform["accuracy"]:.4f}')
        train_losses.append(train_perform['loss'])
        valid_losses.append(valid_perform['loss'])

    plt.plot(train_losses, label='Train Loss')
    plt.plot(valid_losses, label='Valid Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

    return train_perform, valid_perform

net = Net()
net.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

train_perform, valid_perform = train_model(net, trainloader, validateloader, optimizer, criterion, epoch_num, device)

print('Finished Training')
# Out:
# Epoch 1: Train Loss=2.3061, Train Acc=0.0999, Valid Loss=2.3031, Valid Acc=0.1000
# Epoch 2: Train Loss=2.3029, Train Acc=0.1000, Valid Loss=2.3025, Valid Acc=0.1000
# Epoch 3: Train Loss=2.3026, Train Acc=0.1030, Valid Loss=2.3024, Valid Acc=0.1000
# Epoch 4: Train Loss=2.3024, Train Acc=0.1041, Valid Loss=2.3021, Valid Acc=0.1099
# Epoch 5: Train Loss=2.3021, Train Acc=0.1128, Valid Loss=2.3014, Valid Acc=0.1506
# Epoch 6: Train Loss=2.2998, Train Acc=0.1329, Valid Loss=2.2954, Valid Acc=0.1456
# Epoch 7: Train Loss=2.2620, Train Acc=0.1468, Valid Loss=2.1174, Valid Acc=0.1977
# Epoch 8: Train Loss=2.0667, Train Acc=0.1898, Valid Loss=1.9453, Valid Acc=0.2185
# Epoch 9: Train Loss=1.9674, Train Acc=0.2085, Valid Loss=1.9036, Valid Acc=0.2300
# Epoch 10: Train Loss=1.9219, Train Acc=0.2331, Valid Loss=1.8573, Valid Acc=0.2513
# Epoch 11: Train Loss=1.8875, Train Acc=0.2498, Valid Loss=1.8123, Valid Acc=0.2825
# Epoch 12: Train Loss=1.8544, Train Acc=0.2702, Valid Loss=1.7809, Valid Acc=0.2952
# Epoch 13: Train Loss=1.8236, Train Acc=0.2826, Valid Loss=1.7315, Valid Acc=0.3207
# Epoch 14: Train Loss=1.7936, Train Acc=0.2988, Valid Loss=1.7084, Valid Acc=0.3262
# Epoch 15: Train Loss=1.7630, Train Acc=0.3089, Valid Loss=1.7073, Valid Acc=0.3203
# Epoch 16: Train Loss=1.7394, Train Acc=0.3183, Valid Loss=1.6367, Valid Acc=0.3526
# Epoch 17: Train Loss=1.7101, Train Acc=0.3277, Valid Loss=1.6175, Valid Acc=0.3604
# Epoch 18: Train Loss=1.6886, Train Acc=0.3333, Valid Loss=1.5778, Valid Acc=0.3659
# Epoch 19: Train Loss=1.6669, Train Acc=0.3418, Valid Loss=1.5984, Valid Acc=0.3643
# Epoch 20: Train Loss=1.6438, Train Acc=0.3513, Valid Loss=1.5437, Valid Acc=0.3864
# Epoch 21: Train Loss=1.6235, Train Acc=0.3646, Valid Loss=1.4978, Valid Acc=0.4034
# Epoch 22: Train Loss=1.6011, Train Acc=0.3776, Valid Loss=1.4817, Valid Acc=0.4239
# Epoch 23: Train Loss=1.5773, Train Acc=0.3907, Valid Loss=1.4754, Valid Acc=0.4330
# Epoch 24: Train Loss=1.5554, Train Acc=0.3995, Valid Loss=1.4309, Valid Acc=0.4404
# Epoch 25: Train Loss=1.5342, Train Acc=0.4097, Valid Loss=1.4152, Valid Acc=0.4566
# Epoch 26: Train Loss=1.5216, Train Acc=0.4148, Valid Loss=1.4027, Valid Acc=0.4586
# Epoch 27: Train Loss=1.5054, Train Acc=0.4228, Valid Loss=1.3668, Valid Acc=0.4704
# Epoch 28: Train Loss=1.4831, Train Acc=0.4301, Valid Loss=1.3763, Valid Acc=0.4698
# Epoch 29: Train Loss=1.4709, Train Acc=0.4382, Valid Loss=1.3587, Valid Acc=0.4818
# Epoch 30: Train Loss=1.4583, Train Acc=0.4416, Valid Loss=1.3433, Valid Acc=0.4756
# Epoch 31: Train Loss=1.4449, Train Acc=0.4480, Valid Loss=1.3454, Valid Acc=0.4855
# Epoch 32: Train Loss=1.4376, Train Acc=0.4490, Valid Loss=1.3715, Valid Acc=0.4719
# Epoch 33: Train Loss=1.4195, Train Acc=0.4580, Valid Loss=1.3132, Valid Acc=0.4995
# Epoch 34: Train Loss=1.4122, Train Acc=0.4596, Valid Loss=1.3260, Valid Acc=0.4894
# Epoch 35: Train Loss=1.3967, Train Acc=0.4668, Valid Loss=1.3278, Valid Acc=0.4888
# Epoch 36: Train Loss=1.3969, Train Acc=0.4677, Valid Loss=1.2933, Valid Acc=0.4986
# Epoch 37: Train Loss=1.3811, Train Acc=0.4727, Valid Loss=1.2574, Valid Acc=0.5134
# Epoch 38: Train Loss=1.3744, Train Acc=0.4743, Valid Loss=1.2231, Valid Acc=0.5240
# Epoch 39: Train Loss=1.3666, Train Acc=0.4793, Valid Loss=1.3169, Valid Acc=0.4998
# Epoch 40: Train Loss=1.3539, Train Acc=0.4867, Valid Loss=1.2459, Valid Acc=0.5268
# Epoch 41: Train Loss=1.3459, Train Acc=0.4889, Valid Loss=1.2393, Valid Acc=0.5277
# Epoch 42: Train Loss=1.3409, Train Acc=0.4952, Valid Loss=1.2086, Valid Acc=0.5397
# Epoch 43: Train Loss=1.3328, Train Acc=0.4967, Valid Loss=1.2124, Valid Acc=0.5394
# Epoch 44: Train Loss=1.3265, Train Acc=0.5011, Valid Loss=1.2512, Valid Acc=0.5381
# Epoch 45: Train Loss=1.3157, Train Acc=0.5066, Valid Loss=1.2819, Valid Acc=0.5225
# Epoch 46: Train Loss=1.3075, Train Acc=0.5125, Valid Loss=1.2585, Valid Acc=0.5353
# Epoch 47: Train Loss=1.3051, Train Acc=0.5134, Valid Loss=1.2344, Valid Acc=0.5460
# Epoch 48: Train Loss=1.2978, Train Acc=0.5172, Valid Loss=1.1597, Valid Acc=0.5723
# Epoch 49: Train Loss=1.2874, Train Acc=0.5244, Valid Loss=1.1793, Valid Acc=0.5540
# Epoch 50: Train Loss=1.2828, Train Acc=0.5261, Valid Loss=1.1765, Valid Acc=0.5685
# Epoch 51: Train Loss=1.2729, Train Acc=0.5352, Valid Loss=1.1207, Valid Acc=0.5914
# Epoch 52: Train Loss=1.2651, Train Acc=0.5387, Valid Loss=1.1317, Valid Acc=0.5843
# Epoch 53: Train Loss=1.2557, Train Acc=0.5430, Valid Loss=1.1223, Valid Acc=0.5921
# Epoch 54: Train Loss=1.2518, Train Acc=0.5454, Valid Loss=1.1249, Valid Acc=0.5974
# Epoch 55: Train Loss=1.2402, Train Acc=0.5505, Valid Loss=1.1124, Valid Acc=0.5959
# Epoch 56: Train Loss=1.2317, Train Acc=0.5544, Valid Loss=1.1280, Valid Acc=0.5984
# Epoch 57: Train Loss=1.2301, Train Acc=0.5540, Valid Loss=1.1022, Valid Acc=0.6036
# Epoch 58: Train Loss=1.2237, Train Acc=0.5583, Valid Loss=1.1224, Valid Acc=0.5942
# Epoch 59: Train Loss=1.2155, Train Acc=0.5593, Valid Loss=1.0990, Valid Acc=0.6017
# Epoch 60: Train Loss=1.2115, Train Acc=0.5654, Valid Loss=1.1083, Valid Acc=0.5992
# Epoch 61: Train Loss=1.2087, Train Acc=0.5656, Valid Loss=1.0607, Valid Acc=0.6174
# Epoch 62: Train Loss=1.1992, Train Acc=0.5708, Valid Loss=1.0837, Valid Acc=0.6083
# Epoch 63: Train Loss=1.1938, Train Acc=0.5697, Valid Loss=1.0627, Valid Acc=0.6191
# Epoch 64: Train Loss=1.1889, Train Acc=0.5747, Valid Loss=1.0624, Valid Acc=0.6160
# Epoch 65: Train Loss=1.1870, Train Acc=0.5755, Valid Loss=1.0566, Valid Acc=0.6205
# Epoch 66: Train Loss=1.1817, Train Acc=0.5747, Valid Loss=1.0492, Valid Acc=0.6224
# Epoch 67: Train Loss=1.1729, Train Acc=0.5806, Valid Loss=1.0524, Valid Acc=0.6248
# Epoch 68: Train Loss=1.1690, Train Acc=0.5822, Valid Loss=1.0236, Valid Acc=0.6344
# Epoch 69: Train Loss=1.1637, Train Acc=0.5836, Valid Loss=1.0225, Valid Acc=0.6333
# Epoch 70: Train Loss=1.1604, Train Acc=0.5861, Valid Loss=1.0411, Valid Acc=0.6287
# Epoch 71: Train Loss=1.1585, Train Acc=0.5866, Valid Loss=1.0328, Valid Acc=0.6298
# Epoch 72: Train Loss=1.1536, Train Acc=0.5888, Valid Loss=1.0152, Valid Acc=0.6365
# Epoch 73: Train Loss=1.1435, Train Acc=0.5920, Valid Loss=1.0393, Valid Acc=0.6274
# Epoch 74: Train Loss=1.1427, Train Acc=0.5918, Valid Loss=1.0590, Valid Acc=0.6295
# Epoch 75: Train Loss=1.1402, Train Acc=0.5940, Valid Loss=1.0332, Valid Acc=0.6311
# Epoch 76: Train Loss=1.1359, Train Acc=0.5960, Valid Loss=1.0338, Valid Acc=0.6333
# Epoch 77: Train Loss=1.1326, Train Acc=0.5972, Valid Loss=1.0286, Valid Acc=0.6336
# Epoch 78: Train Loss=1.1241, Train Acc=0.5995, Valid Loss=1.0000, Valid Acc=0.6455
# Epoch 79: Train Loss=1.1244, Train Acc=0.6015, Valid Loss=0.9827, Valid Acc=0.6492
# Epoch 80: Train Loss=1.1232, Train Acc=0.6015, Valid Loss=0.9954, Valid Acc=0.6466
# Epoch 81: Train Loss=1.1202, Train Acc=0.6008, Valid Loss=1.0048, Valid Acc=0.6411
# Epoch 82: Train Loss=1.1141, Train Acc=0.6041, Valid Loss=0.9953, Valid Acc=0.6455
# Epoch 83: Train Loss=1.1110, Train Acc=0.6051, Valid Loss=0.9940, Valid Acc=0.6466
# Epoch 84: Train Loss=1.1073, Train Acc=0.6070, Valid Loss=0.9713, Valid Acc=0.6546
# Epoch 85: Train Loss=1.1044, Train Acc=0.6087, Valid Loss=0.9786, Valid Acc=0.6531
# Epoch 86: Train Loss=1.1025, Train Acc=0.6088, Valid Loss=0.9953, Valid Acc=0.6467
# Epoch 87: Train Loss=1.0951, Train Acc=0.6116, Valid Loss=1.0057, Valid Acc=0.6432
# Epoch 88: Train Loss=1.0920, Train Acc=0.6129, Valid Loss=1.0161, Valid Acc=0.6354
# Epoch 89: Train Loss=1.0925, Train Acc=0.6153, Valid Loss=0.9786, Valid Acc=0.6549
# Epoch 90: Train Loss=1.0866, Train Acc=0.6160, Valid Loss=0.9648, Valid Acc=0.6568
# Epoch 91: Train Loss=1.0873, Train Acc=0.6154, Valid Loss=1.0060, Valid Acc=0.6460
# Epoch 92: Train Loss=1.0797, Train Acc=0.6160, Valid Loss=1.0054, Valid Acc=0.6455
# Epoch 93: Train Loss=1.0769, Train Acc=0.6178, Valid Loss=0.9681, Valid Acc=0.6581
# Epoch 94: Train Loss=1.0766, Train Acc=0.6204, Valid Loss=0.9878, Valid Acc=0.6558
# Epoch 95: Train Loss=1.0727, Train Acc=0.6218, Valid Loss=0.9488, Valid Acc=0.6650
# Epoch 96: Train Loss=1.0700, Train Acc=0.6217, Valid Loss=0.9632, Valid Acc=0.6609
# Epoch 97: Train Loss=1.0654, Train Acc=0.6261, Valid Loss=0.9546, Valid Acc=0.6592
# Epoch 98: Train Loss=1.0641, Train Acc=0.6263, Valid Loss=0.9653, Valid Acc=0.6634
# Epoch 99: Train Loss=1.0599, Train Acc=0.6262, Valid Loss=0.9385, Valid Acc=0.6685
# Epoch 100: Train Loss=1.0613, Train Acc=0.6267, Valid Loss=0.9673, Valid Acc=0.6603
# Epoch 101: Train Loss=1.0554, Train Acc=0.6291, Valid Loss=0.9545, Valid Acc=0.6644
# Epoch 102: Train Loss=1.0524, Train Acc=0.6293, Valid Loss=0.9198, Valid Acc=0.6746
# Epoch 103: Train Loss=1.0504, Train Acc=0.6293, Valid Loss=0.9403, Valid Acc=0.6715
# Epoch 104: Train Loss=1.0531, Train Acc=0.6315, Valid Loss=0.9214, Valid Acc=0.6752
# Epoch 105: Train Loss=1.0454, Train Acc=0.6314, Valid Loss=0.9643, Valid Acc=0.6654
# Epoch 106: Train Loss=1.0408, Train Acc=0.6342, Valid Loss=0.9309, Valid Acc=0.6703
# Epoch 107: Train Loss=1.0447, Train Acc=0.6332, Valid Loss=0.9175, Valid Acc=0.6781
# Epoch 108: Train Loss=1.0403, Train Acc=0.6354, Valid Loss=0.9288, Valid Acc=0.6736
# Epoch 109: Train Loss=1.0318, Train Acc=0.6380, Valid Loss=0.9195, Valid Acc=0.6772
# Epoch 110: Train Loss=1.0375, Train Acc=0.6367, Valid Loss=0.9389, Valid Acc=0.6700
# Epoch 111: Train Loss=1.0322, Train Acc=0.6392, Valid Loss=0.9088, Valid Acc=0.6805
# Epoch 112: Train Loss=1.0301, Train Acc=0.6381, Valid Loss=0.8992, Valid Acc=0.6831
# Epoch 113: Train Loss=1.0271, Train Acc=0.6402, Valid Loss=0.9220, Valid Acc=0.6761
# Epoch 114: Train Loss=1.0229, Train Acc=0.6415, Valid Loss=0.9126, Valid Acc=0.6778
# Epoch 115: Train Loss=1.0175, Train Acc=0.6444, Valid Loss=0.9353, Valid Acc=0.6745
# Epoch 116: Train Loss=1.0201, Train Acc=0.6440, Valid Loss=0.9210, Valid Acc=0.6788
# Epoch 117: Train Loss=1.0166, Train Acc=0.6451, Valid Loss=0.9197, Valid Acc=0.6772
# Epoch 118: Train Loss=1.0139, Train Acc=0.6435, Valid Loss=0.9232, Valid Acc=0.6783
# Epoch 119: Train Loss=1.0098, Train Acc=0.6471, Valid Loss=0.9463, Valid Acc=0.6662
# Epoch 120: Train Loss=1.0128, Train Acc=0.6450, Valid Loss=0.9328, Valid Acc=0.6744
# Epoch 121: Train Loss=1.0102, Train Acc=0.6470, Valid Loss=0.9130, Valid Acc=0.6772
# Epoch 122: Train Loss=1.0047, Train Acc=0.6496, Valid Loss=0.9075, Valid Acc=0.6838
# Epoch 123: Train Loss=1.0020, Train Acc=0.6482, Valid Loss=0.9058, Valid Acc=0.6830
# Epoch 124: Train Loss=1.0019, Train Acc=0.6482, Valid Loss=0.9166, Valid Acc=0.6783
# Epoch 125: Train Loss=0.9934, Train Acc=0.6514, Valid Loss=0.9141, Valid Acc=0.6793
# Epoch 126: Train Loss=0.9977, Train Acc=0.6503, Valid Loss=0.8899, Valid Acc=0.6909
# Epoch 127: Train Loss=0.9989, Train Acc=0.6502, Valid Loss=0.9089, Valid Acc=0.6793
# Epoch 128: Train Loss=0.9969, Train Acc=0.6526, Valid Loss=0.9134, Valid Acc=0.6818
# Epoch 129: Train Loss=0.9943, Train Acc=0.6533, Valid Loss=0.9439, Valid Acc=0.6732
# Epoch 130: Train Loss=0.9922, Train Acc=0.6541, Valid Loss=0.8980, Valid Acc=0.6850
# Epoch 131: Train Loss=0.9884, Train Acc=0.6544, Valid Loss=0.8959, Valid Acc=0.6863
# Epoch 132: Train Loss=0.9881, Train Acc=0.6556, Valid Loss=0.8943, Valid Acc=0.6877
# Epoch 133: Train Loss=0.9902, Train Acc=0.6548, Valid Loss=0.8906, Valid Acc=0.6907
# Epoch 134: Train Loss=0.9828, Train Acc=0.6576, Valid Loss=0.9059, Valid Acc=0.6880
# Epoch 135: Train Loss=0.9853, Train Acc=0.6550, Valid Loss=0.8895, Valid Acc=0.6878
# Epoch 136: Train Loss=0.9815, Train Acc=0.6569, Valid Loss=0.8666, Valid Acc=0.6959
# Epoch 137: Train Loss=0.9789, Train Acc=0.6589, Valid Loss=0.8793, Valid Acc=0.6924
# Epoch 138: Train Loss=0.9795, Train Acc=0.6582, Valid Loss=0.8814, Valid Acc=0.6901
# Epoch 139: Train Loss=0.9749, Train Acc=0.6610, Valid Loss=0.8789, Valid Acc=0.6906
# Epoch 140: Train Loss=0.9779, Train Acc=0.6596, Valid Loss=0.8988, Valid Acc=0.6860
# Epoch 141: Train Loss=0.9794, Train Acc=0.6606, Valid Loss=0.9052, Valid Acc=0.6817
# Epoch 142: Train Loss=0.9750, Train Acc=0.6603, Valid Loss=0.8744, Valid Acc=0.6939
# Epoch 143: Train Loss=0.9709, Train Acc=0.6629, Valid Loss=0.8653, Valid Acc=0.6955
# Epoch 144: Train Loss=0.9716, Train Acc=0.6611, Valid Loss=0.8853, Valid Acc=0.6883
# Epoch 145: Train Loss=0.9685, Train Acc=0.6624, Valid Loss=0.9028, Valid Acc=0.6857
# Epoch 146: Train Loss=0.9705, Train Acc=0.6615, Valid Loss=0.8738, Valid Acc=0.6954
# Epoch 147: Train Loss=0.9672, Train Acc=0.6646, Valid Loss=0.9015, Valid Acc=0.6888
# Epoch 148: Train Loss=0.9623, Train Acc=0.6638, Valid Loss=0.8676, Valid Acc=0.6968
# Epoch 149: Train Loss=0.9620, Train Acc=0.6644, Valid Loss=0.8529, Valid Acc=0.7019
# Epoch 150: Train Loss=0.9627, Train Acc=0.6644, Valid Loss=0.8832, Valid Acc=0.6919
# Epoch 151: Train Loss=0.9602, Train Acc=0.6671, Valid Loss=0.8841, Valid Acc=0.6909
# Epoch 152: Train Loss=0.9552, Train Acc=0.6672, Valid Loss=0.8730, Valid Acc=0.6959
# Epoch 153: Train Loss=0.9620, Train Acc=0.6639, Valid Loss=0.8797, Valid Acc=0.6972
# Epoch 154: Train Loss=0.9585, Train Acc=0.6664, Valid Loss=0.8666, Valid Acc=0.6973
# Epoch 155: Train Loss=0.9580, Train Acc=0.6675, Valid Loss=0.8918, Valid Acc=0.6925
# Epoch 156: Train Loss=0.9522, Train Acc=0.6711, Valid Loss=0.8705, Valid Acc=0.6998
# Epoch 157: Train Loss=0.9572, Train Acc=0.6689, Valid Loss=0.8880, Valid Acc=0.6935
# Epoch 158: Train Loss=0.9535, Train Acc=0.6686, Valid Loss=0.8743, Valid Acc=0.6976
# Epoch 159: Train Loss=0.9570, Train Acc=0.6683, Valid Loss=0.8568, Valid Acc=0.7017
# Epoch 160: Train Loss=0.9495, Train Acc=0.6704, Valid Loss=0.8638, Valid Acc=0.6992
# Epoch 161: Train Loss=0.9480, Train Acc=0.6717, Valid Loss=0.8692, Valid Acc=0.6989
# Epoch 162: Train Loss=0.9474, Train Acc=0.6698, Valid Loss=0.8598, Valid Acc=0.6988
# Epoch 163: Train Loss=0.9452, Train Acc=0.6699, Valid Loss=0.8659, Valid Acc=0.7022
# Epoch 164: Train Loss=0.9448, Train Acc=0.6728, Valid Loss=0.8547, Valid Acc=0.7018
# Epoch 165: Train Loss=0.9419, Train Acc=0.6723, Valid Loss=0.8486, Valid Acc=0.7052
# Epoch 166: Train Loss=0.9451, Train Acc=0.6724, Valid Loss=0.8740, Valid Acc=0.6974
# Epoch 167: Train Loss=0.9396, Train Acc=0.6735, Valid Loss=0.8809, Valid Acc=0.6956
# Epoch 168: Train Loss=0.9417, Train Acc=0.6736, Valid Loss=0.8583, Valid Acc=0.7006
# Epoch 169: Train Loss=0.9388, Train Acc=0.6742, Valid Loss=0.8525, Valid Acc=0.7045
# Epoch 170: Train Loss=0.9366, Train Acc=0.6756, Valid Loss=0.8483, Valid Acc=0.7032
# Epoch 171: Train Loss=0.9363, Train Acc=0.6755, Valid Loss=0.8515, Valid Acc=0.7001
# Epoch 172: Train Loss=0.9367, Train Acc=0.6758, Valid Loss=0.8406, Valid Acc=0.7057
# Epoch 173: Train Loss=0.9363, Train Acc=0.6775, Valid Loss=0.8634, Valid Acc=0.7021
# Epoch 174: Train Loss=0.9299, Train Acc=0.6759, Valid Loss=0.8374, Valid Acc=0.7087
# Epoch 175: Train Loss=0.9340, Train Acc=0.6777, Valid Loss=0.8650, Valid Acc=0.6979
# Epoch 176: Train Loss=0.9325, Train Acc=0.6760, Valid Loss=0.8676, Valid Acc=0.7042
# Epoch 177: Train Loss=0.9320, Train Acc=0.6757, Valid Loss=0.9003, Valid Acc=0.6894
# Epoch 178: Train Loss=0.9321, Train Acc=0.6780, Valid Loss=0.8362, Valid Acc=0.7073
# Epoch 179: Train Loss=0.9291, Train Acc=0.6763, Valid Loss=0.8494, Valid Acc=0.7075
# Epoch 180: Train Loss=0.9250, Train Acc=0.6793, Valid Loss=0.8730, Valid Acc=0.6974
# Epoch 181: Train Loss=0.9257, Train Acc=0.6801, Valid Loss=0.8309, Valid Acc=0.7094
# Epoch 182: Train Loss=0.9274, Train Acc=0.6784, Valid Loss=0.8504, Valid Acc=0.7050
# Epoch 183: Train Loss=0.9242, Train Acc=0.6798, Valid Loss=0.8452, Valid Acc=0.7080
# Epoch 184: Train Loss=0.9248, Train Acc=0.6807, Valid Loss=0.9038, Valid Acc=0.6891
# Epoch 185: Train Loss=0.9242, Train Acc=0.6784, Valid Loss=0.8400, Valid Acc=0.7063
# Epoch 186: Train Loss=0.9192, Train Acc=0.6822, Valid Loss=0.8534, Valid Acc=0.7024
# Epoch 187: Train Loss=0.9243, Train Acc=0.6814, Valid Loss=0.8507, Valid Acc=0.7077
# Epoch 188: Train Loss=0.9219, Train Acc=0.6803, Valid Loss=0.8319, Valid Acc=0.7110
# Epoch 189: Train Loss=0.9171, Train Acc=0.6827, Valid Loss=0.8377, Valid Acc=0.7080
# Epoch 190: Train Loss=0.9171, Train Acc=0.6828, Valid Loss=0.8615, Valid Acc=0.7018
# Epoch 191: Train Loss=0.9195, Train Acc=0.6818, Valid Loss=0.8371, Valid Acc=0.7118
# Epoch 192: Train Loss=0.9226, Train Acc=0.6777, Valid Loss=0.8485, Valid Acc=0.7079
# Epoch 193: Train Loss=0.9164, Train Acc=0.6828, Valid Loss=0.8269, Valid Acc=0.7134
# Epoch 194: Train Loss=0.9144, Train Acc=0.6837, Valid Loss=0.8451, Valid Acc=0.7039
# Epoch 195: Train Loss=0.9130, Train Acc=0.6826, Valid Loss=0.8226, Valid Acc=0.7159
# Epoch 196: Train Loss=0.9089, Train Acc=0.6846, Valid Loss=0.8384, Valid Acc=0.7073
# Epoch 197: Train Loss=0.9111, Train Acc=0.6855, Valid Loss=0.8372, Valid Acc=0.7091
# Epoch 198: Train Loss=0.9107, Train Acc=0.6845, Valid Loss=0.8263, Valid Acc=0.7118
# Epoch 199: Train Loss=0.9116, Train Acc=0.6834, Valid Loss=0.8386, Valid Acc=0.7082
# Epoch 200: Train Loss=0.9072, Train Acc=0.6862, Valid Loss=0.8155, Valid Acc=0.7160
# Finished Training

# %% [markdown]
# ### Saving our model

# %%
PATH = './cinic_net.pth'
torch.save(net.state_dict(), PATH)

# %% [markdown]
# ### Testing the model

# %%
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
correct = 0
total = 0
with torch.no_grad():
    for data in testloader:
        images, labels = data
        images = images.to(device)
        labels = labels.to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(len(labels)):
            label = labels[i]
            if class_total[label] == 0:
                class_correct[label] = 0
            else:
                class_correct[label] += c[i].item()
            class_total[label] += 1
            correct += c[i].item()
            total += 1

for i in range(10):
    if class_total[i] == 0:
        print('Accuracy of %5s : N/A (no test images for this class)' % (classes[i]))
    else:
        print('Accuracy of %5s : %2d %%' % (classes[i], 100 * class_correct[i] / class_total[i]))

print('Overall accuracy of the network on the test images: %2d %%' % (100 * correct / total))
# Out:
# Accuracy of airplane : 78 %
# Accuracy of automobile : 75 %
# Accuracy of  bird : 71 %
# Accuracy of   cat : 59 %
# Accuracy of  deer : 68 %
# Accuracy of   dog : 43 %
# Accuracy of  frog : 83 %
# Accuracy of horse : 77 %
# Accuracy of  ship : 78 %
# Accuracy of truck : 77 %
# Overall accuracy of the network on the test images: 71 %
